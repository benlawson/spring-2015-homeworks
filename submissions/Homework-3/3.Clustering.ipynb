# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering the data from the Mayor's 24-hour hotline in Boston

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will do a clustering analysis on the 311 calls that we used in the previous homework. We will focus on choosing a value for k, clustering based on multiple features and detecting outliers.
#
# ---------------------------

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler 
import numpy as np
from datetime import datetime

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv')

# %% [markdown]
# ## Step 1. Simple clustering

# %% [markdown]
# The first thing that we will try is to cluster the geolocation data of the calls. The geolocation of a record consists of a pair `(latitude, longitude)`, which represents the position of the record on the map. Since the dataset that we have spans only a small geographic location, i.e. Boston, we will use the Euclidean distance when measuring how close two points are. Techinically, we should pick a [projection](https://github.com/mbostock/d3/wiki/Geo-Projections) in order to transform the data into 2d, and measure  the Euclidean distance in the projected space.

# %% [markdown]
# Since we are dealing with numeric data, we might consider centering and normalizing them. In order to do that, check the [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler) from `scikit-learn`.

# %% [markdown]
# For exampe, the result of a clustering with 10 clusters is the following:
#
#
# ![A clustering of the locations of the calls for k=10](clusters10.png)

# %% [markdown]
# Filter the dataset to get the latitude and longitude, transform it as required and run the k-means clustering algorithm. Argue about the number of clusters you used. **(pts 50)**

# %%
locations = boston.loc[:,['LATITUDE','LONGITUDE']]
print locations.head()
scaler = StandardScaler()
scaler.fit_transform(locations)
print locations.head()
# Out:
#    LATITUDE  LONGITUDE
# 0   42.3574   -71.0648
# 1   42.3474   -71.0944
# 2   42.3474   -71.0944
# 3   42.2711   -71.1464
# 4   42.3254   -71.0574
#    LATITUDE  LONGITUDE
# 0  0.957006   0.561375
# 1  0.668763  -0.273099
# 2  0.668763  -0.273099
# 3 -1.530531  -1.739066
# 4  0.034629   0.769993

# %%
print locations.tail()
# Out:
#        LATITUDE  LONGITUDE
# 46693 -0.158494  -0.602941
# 46694 -1.129873  -0.958156
# 46695 -1.432528  -0.239269
# 46696  1.014655   0.733344
# 46697 -1.420999  -0.239269

# %%
#taken from lecture notes
kmeans = KMeans(init='k-means++', n_clusters=15, n_init=10)
kmeans.fit_predict(locations)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_
'''
print "The total error of the clustering is: ", error
print '\nCluster labels'
print labels
print '\n Cluster Centroids'
print centroids

locations['labels'] = labels
print locations
'''
# Out:
# '\nprint "The total error of the clustering is: ", error\nprint \'\nCluster labels\'\nprint labels\nprint \'\n Cluster Centroids\'\nprint centroids\n\nlocations[\'labels\'] = labels\nprint locations\n'

# %%
print centroids[0][0]
print locations.info()
# Out:
# -1.29261284679
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 2 columns):
# LATITUDE     46698 non-null float64
# LONGITUDE    46698 non-null float64
# dtypes: float64(2)None

# %%
#code by Harry taken from piazza
fig, ax = plt.subplots(1,1,figsize=(10,10))
# since I have 15 clusters instead, I need 15 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together (I think?)
cmap = sns.color_palette("bright", n_colors=10)
cmap.extend(sns.hls_palette(n_colors=5, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(labels)):
    point_indices = np.where(labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(locations['LONGITUDE'][point_indices],locations['LATITUDE'][point_indices], s=25, alpha=0.2, c=cmap[i], marker='+')

# %%
#this function is from lecture
# By Evamari Terzi and Harry 
def evaluate_clusters(X,max_clusters):
    error = np.zeros(max_clusters+1)
    error[0] = 0;
    for k in range(1,max_clusters+1):
        kmeans = KMeans(init='k-means++', n_clusters=k, n_init=10)
        kmeans.fit_predict(X)
        error[k] = kmeans.inertia_

    plt.plot(range(1,len(error)),error[1:])
    plt.xlabel('Number of clusters')
    plt.ylabel('Error')

evaluate_clusters(locations,20)

# %% [markdown]
# -----

# %% [markdown]
# ### Reasoning for 15 Clusters

# %% [markdown]
# According to the graph of the number of clusters vs error, a logical choice for the number of clusters would be around 4 clusters because this is where the error significantly drops. However, I choose to use 15 clusers because there are 15 neighboorhoods in Boston and the clusters *almost* match up with a map of the neighborhoods.

# %% [markdown]
# ## Step 2. Using multiple features

# %% [markdown]
# The next step in our analysis is to use more features than just the geolocation of a record (whose clustering only gives us information about the neighborhoods, which should not be a huge revelation!) Filter the dataset to get more features, transform them as required and compute another clustering. You should argue about the quality of your clustering and use domain knowledge (i.e. the fact that you are locals) to explore the clusters you produced and present them to the reader. **(pts 30)**

# %%
def lengthrow(row):
    return row.CLOSED_DT - row.OPEN_DT

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv', parse_dates=[1,2,3])
date = datetime.strptime("2015-2-28 00:00:00", "%Y-%m-%d %X")
boston['CLOSED_DT'].fillna(value=date,inplace=True)
boston.OPEN_DT.fillna(value=date,inplace=True)


def lengthrow(row):
    return row.CLOSED_DT - row.OPEN_DT
boston['REPAIR_TIME'] = boston.apply(lengthrow, axis = 1)
print boston.REPAIR_TIME
# Out:
# 0     1 days, 08:48:33
# 1     1 days, 15:52:20
# 2    57 days, 23:34:24
# 3    57 days, 22:14:23
# 4     1 days, 06:44:01
# 5     1 days, 06:01:14
# 6     0 days, 02:10:17
# 7    57 days, 20:13:45
# 8     0 days, 01:05:20
# 9    57 days, 19:47:20
# 10    0 days, 04:18:49
# 11   57 days, 16:32:47
# 12    0 days, 20:51:03
# 13   57 days, 15:34:08
# 14   57 days, 15:24:16
# ...
# 46683   13 days, 01:27:25
# 46684   13 days, 01:19:29
# 46685   13 days, 01:15:23
# 46686   13 days, 01:14:54
# 46687   13 days, 01:04:59
# 46688   13 days, 01:02:14
# 46689   13 days, 00:39:40
# 46690   13 days, 00:33:03
# 46691   13 days, 00:31:30
# 46692   13 days, 00:30:38
# 46693   13 days, 00:22:09
# 46694   13 days, 00:18:35
# 46695   13 days, 00:13:41
# 46696   13 days, 00:06:51
# 46697   12 days, 23:59:43
# Name: REPAIR_TIME, Length: 46698, dtype: timedelta64[ns]

# %%
zipcodes = boston.loc[:,['LOCATION_ZIPCODE','REPAIR_TIME','LONGITUDE']]
print zipcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46698 entries, 0 to 46697
# Data columns (total 3 columns):
# LOCATION_ZIPCODE    35291 non-null float64
# REPAIR_TIME         46698 non-null timedelta64[ns]
# LONGITUDE           46698 non-null float64
# dtypes: float64(2), timedelta64[ns](1)None

# %%
#code by Harry taken from piazza
fig, ax = plt.subplots(1,1,figsize=(10,10))
# since I have 15 clusters instead, I need 15 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together (I think?)
cmap = sns.color_palette("bright", n_colors=10)
cmap.extend(sns.hls_palette(n_colors=5, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(labels)):
    point_indices = np.where(labels == label)[0]
    point_indices = point_indices.tolist()
sortedZIPs = .LOCATIONS_ZIPCODES
plt.plot(zipcodes['LONGITUDE'],zipcodes['REPAIR_TIME'], )

# %%
kmeans_new = KMeans(init='k-means++', n_clusters=15, n_init=10)
kmeans_new.fit_predict(zipcodes)
centroids_new = kmeans_new.cluster_centers_
labels_new = kmeans_new.labels_
error_new = kmeans_new.inertia_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0f0871e7b4ba> in <module>()
#       1 kmeans_new = KMeans(init='k-means++', n_clusters=15, n_init=10)
# ----> 2 kmeans_new.fit_predict(zipcodes)
#       3 centroids_new = kmeans_new.cluster_centers_
#       4 labels_new = kmeans_new.labels_
#       5 error_new = kmeans_new.inertia_
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\cluster\k_means_.pyc in fit_predict(self, X)
#     738         predict(X).
#     739         """
# --> 740         return self.fit(X).labels_
#     741
#     742     def fit_transform(self, X, y=None):
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\cluster\k_means_.pyc in fit(self, X, y)
#     722         """
#     723         random_state = check_random_state(self.random_state)
# --> 724         X = self._check_fit_data(X)
#     725
#     726         self.cluster_centers_, self.labels_, self.inertia_ = k_means(
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\cluster\k_means_.pyc in _check_fit_data(self, X)
#     688     def _check_fit_data(self, X):
#     689         """Verify that the number of samples given is larger than k"""
# --> 690         X = atleast2d_or_csr(X, dtype=np.float64)
#     691         if X.shape[0] < self.n_clusters:
#     692             raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in _atleast2d_or_sparse(X, dtype, order, copy, sparse_class, convmethod, check_same_type, force_all_finite)
#     140     else:
#     141         X = array2d(X, dtype=dtype, order=order, copy=copy,
# --> 142                     force_all_finite=force_all_finite)
#     143     return X
#     144
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in array2d(X, dtype, order, copy, force_all_finite)
#     120     X_2d = np.asarray(np.atleast_2d(X), dtype=dtype, order=order)
#     121     if force_all_finite:
# --> 122         _assert_all_finite(X_2d)
#     123     if X is X_2d and copy:
#     124         X_2d = safe_copy(X_2d)
#
# c:\Users\Ben\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in _assert_all_finite(X)
#      41             and not np.isfinite(X).all()):
#      42         raise ValueError("Input contains NaN, infinity"
# ---> 43                          " or a value too large for %r." % X.dtype)
#      44
#      45
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %% [markdown]
# -----

# %% [markdown]
# ## Step 3. Detecting outliers

# %% [markdown]
# Now that we have a clustering of the records in the dataset, we can detect the outlying ones. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(pts 20)**

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
